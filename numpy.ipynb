# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('images/sky.jpeg')

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (332, 500, 3)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
# R G B   0: Black  255 :red
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (332, 500, 3)

# %%
pic_red[:,:,1]
# Out:
# array([[199, 199, 200, ..., 107,  99,  96],
#        [199, 199, 199, ..., 107, 103, 100],
#        [198, 198, 199, ..., 107, 107, 106],
#        ...,
#        [ 68,  68,  67, ...,  67,  69,  75],
#        [ 68,  67,  67, ...,  69,  73,  80],
#        [ 67,  67,  67, ...,  68,  73,  82]], dtype=uint8)

# %%
plt.imshow(pic_red[:,:,1])

# %%
# RED CHANNEL
plt.imshow(pic_red[:,:,0],cmap = 'gray')

# %%
# Blue CHANNEL
plt.imshow(pic_red[:,:,2],cmap='gray')

# %%
pic_red[:,:,1] = 0

# %%
plt.imshow(pic_red)

# %%
pic_red[:,:,2] = 0

# %%
plt.imshow(pic_red)

# %%
pic_red[:,:,2].shape
# Out:
# (332, 500)

# %%
pic_red.shape
# Out:
# (332, 500, 3)
