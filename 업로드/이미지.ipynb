# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('images/dogs.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (339, 510, 3)

# %%
plt.imshow(img)

# %%
# MATPLOTLIB --> R G B  // RED GREEN BLUE
# OPENCV --> B G R // BLUE GREEN BLUE

# %%
# 색이 이상해지므로 R G B 맷플로릿 방법으로 바꿔주자

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('images/dogs.jpg',cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (339, 510, 3)

# %%
new_img = cv2.resize(fix_img,(1000,500))

# %%
plt.imshow(new_img)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
new_img = cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (170, 255, 3)

# %%
new_img = cv2.flip(fix_img,-1)
plt.imshow(new_img)

# %%
type(fix_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('totally_new.jpg',fix_img)
# Out:
# True

# %%
fig= plt.figure(figsize=(2,2))
ax = fig.add_subplot(111)
ax.imshow(fix_img)

# %%
import cv2

img = cv2.imread('images/dogs.jpg')

cv2.imshow('puppy',img)

cv2.waitKey()
